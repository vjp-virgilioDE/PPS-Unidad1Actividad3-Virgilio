# %%
module_code = """""
def suma(a, b):
    
    return a + b

def resta(a, b):
    
    return a - b

def multiplicacion(a, b):
    
    return a * b

def division(a, b):
    
    if b == 0:
        return "Error: División entre cero no permitida"
    return a / b

def isNumber(arg):
    
    try:
        float(arg)  # Intentamos convertir a número
        return True
    except ValueError:
        return False

def mayorCero(num):
    
    return num > 0
"""""


with open("mi_modulo.py", "w") as file:
    file.write(module_code)

print("Módulo 'mi_modulo.py' creado con éxito.")



program_code = """""
import mi_modulo

def main():
    print("\nBienvenido al programa de operaciones matemáticas")
    
    # Solicitar dos números al usuario
    while True:
        num1 = input("\nIntroduce el primer número: ")
        num2 = input("Introduce el segundo número: ")
        
        if mi_modulo.isNumber(num1) and mi_modulo.isNumber(num2):
            num1 = float(num1)
            num2 = float(num2)
            break
        else:
            print("Error: Ambos valores deben ser números. Inténtalo de nuevo.")
    
    # Mostrar el menú de operaciones
    while True:
        print("\nSelecciona la operación que deseas realizar:")
        print("1. Suma")
        print("2. Resta")
        print("3. Multiplicación")
        print("4. División")
        print("5. Salir")
        
        opcion = input("\nIntroduce tu opción (1-5): ")
        
        if opcion == "1":
            print(f"\nResultado de la suma: {mi_modulo.suma(num1, num2)}")
        elif opcion == "2":
            print(f"\nResultado de la resta: {mi_modulo.resta(num1, num2)}")
        elif opcion == "3":
            print(f"\nResultado de la multiplicación: {mi_modulo.multiplicacion(num1, num2)}")
        elif opcion == "4":
            print(f"\nResultado de la división: {mi_modulo.division(num1, num2)}")
        elif opcion == "5":
            print("\nGracias por usar el programa. ¡Adiós!")
            break
        else:
            print("Opción inválida. Por favor, selecciona una opción del 1 al 5.")

if __name__ == "__main__":
    main()
"""""


with open("programa_interactivo.py", "w") as file:
    file.write(program_code)

print("Programa interactivo 'programa_interactivo.py' creado con éxito.")
# Out:
# Módulo 'mi_modulo.py' creado con éxito.
# Programa interactivo 'programa_interactivo.py' creado con éxito.
